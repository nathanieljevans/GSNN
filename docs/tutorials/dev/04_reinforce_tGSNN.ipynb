# %%
import networkx as nx 
from matplotlib import pyplot as plt
import numpy as np
from scipy.integrate import solve_ivp
import networkx as nx
import torch
import copy
from torch.distributions.bernoulli import Bernoulli
import pandas as pd

from gsnn.simulate.nx2pyg import nx2pyg
from gsnn.simulate.datasets import simulate_3_in_3_out

from gsnn.optim.Environment import Environment
from gsnn.optim.RewardScaler import RewardScaler
from gsnn.models.tGSNN import tGSNN

from sklearn.metrics import roc_auc_score
from gsnn.optim.REINFORCE import REINFORCE
import argparse

from sklearn.metrics import confusion_matrix
import seaborn as sbn

# for reproducibility 
torch.manual_seed(0)
np.random.seed(0)

# %load_ext autoreload
# %autoreload 2
# Out:
# /home/teddy/miniconda3/envs/gsnn-lib/lib/python3.12/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /home/teddy/miniconda3/envs/gsnn-lib/lib/python3.12/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %% [markdown]
# # Reinforcement learning for structure optimization
#
# In many cases, prior knowledge is incomplete, noisy or spurrious for specific prediction tasks. In this example, we will demonstrate how we can use the reinforcement learning for the optimal selection of prior knowledge.
#
# NOTE: This procedure requires running many sequential training loops, and therefore is not applicable to large graphs or large datasets (where training time is significant). That said, RL's ability to identify true edges does offer a convenient evaluation of our premise that *the true graph structure should result in better performances than alternative graph structures*.
#
#
# Thoughts:
# In my experience playing with the RL parameters, it appears that this approach is specific but not sensitive to true edges. For instance, the true input edges are almost always included (across different hyper-params), but some false edges also may have high policy probabilities. This suggests that the model is robust to noisy edges (as long as the true edge is included), but also may limit the ability to identify the true graph. Including a nonzero policy decay (L1 regularization on policy probabilities), seems to help improve the sensitivity of true edges.
#
# Additionally, I've found that the "auc" (sum of all epoch test scores) reward type seens to be more resilient than "best" or "last", which may suggest that the true graph has advantages in early training, but less so in terms of late training or best test performance.
#
# It is also worth noting that the rewards are farily noisy (same action can result in a varied rewards), which may account for why the "best_action" is not always the true action (graph), whereas the policy is often a more robust metric of the true action.

# %%
G, pos, x_train, x_test, y_train, y_test, \
    input_nodes, function_nodes, output_nodes = simulate_3_in_3_out(n_train=50, n_test=500,
                                                                    noise_scale=0.5, zscorey=True)

plt.figure(figsize=(8, 6))
nx.draw_networkx(G, pos, with_labels=True, node_color='lightblue', node_size=500, font_size=10, arrowstyle='->', arrowsize=20)
plt.title("Dummy Graph: 3 Inputs, 3 Outputs, 5 Function Nodes")
plt.show()

# %%
data = nx2pyg(G, input_nodes, function_nodes, output_nodes) 

# add some false edges 
edge_index_dict = copy.deepcopy(data.edge_index_dict)

# add some false input edges 
edge_index_dict['input', 'to', 'function'] = torch.cat((edge_index_dict['input', 'to', 'function'], 
                                                         torch.tensor([[0, 1, 2, 1], 
                                                                       [1, 0, 1, 2]], 
                                                                       dtype=torch.long)), dim=-1)

# %%
input_edges = set([(i.item(),j.item()) for i,j in data.edge_index_dict['input', 'to', 'function'].T])

action_label_dict = {}
action_label_dict[('input', 'to', 'function')] = [(i.item(), j.item()) in input_edges for i,j in edge_index_dict['input', 'to', 'function'].T] 

true_action = 1.*np.array(action_label_dict[('input', 'to', 'function')])

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
train_dataset = torch.utils.data.TensorDataset(x_train, y_train) 
test_dataset = torch.utils.data.TensorDataset(x_test, y_test)

# %%
# GSNN model parameters
model_kwargs = {'edge_index_dict'                 : edge_index_dict, 
                    'node_names_dict'                 : data.node_names_dict,
                    'd_model': 4, 
                    'nhead':1, 
                    'num_layers':6, 
                    'activation':'gelu', 
                    'add_function_self_edges':False}

# GSNN training parameters
training_kwargs = {'lr':1e-3, 
                    'max_epochs':250, 
                    'batch':250,
                    'workers':1, 
                    'weight_decay':1e-2}

# the action edge dict will be used to index the action for each edge 
# if and edge key is not provided, those values will not be optimized (always present)
action_edge_dict = {('input', 'to', 'function'): torch.arange(edge_index_dict['input', 'to', 'function'].shape[1])} 

n_actions = sum([torch.unique(v).numel() for v in action_edge_dict.values()])

env = Environment(action_edge_dict, train_dataset, test_dataset, model_kwargs, 
                 training_kwargs, metric='r2', reward_type='best', verbose=False,
                 raise_error_on_fail=True, model=tGSNN)

hoptim = REINFORCE(env, n_actions, action_labels=true_action, clip=10, eps=1e-8, warmup=3, verbose=True, 
                        entropy=0., entropy_decay=0.99, min_entropy=0.0, window=10,
                        init_prob=0.5, lr=1e-1, policy_decay=1.)

for iter in range(100): 
    hoptim.step()
# Out:
# 	 --> iter: 1 || auroc 0.500 || acc: 0.571 || prob(true_action): 7.812E-03 || last reward: -0.011
# 	 --> iter: 2 || auroc 0.500 || acc: 0.571 || prob(true_action): 7.812E-03 || last reward: -0.017
# 	 --> iter: 3 || auroc 0.500 || acc: 0.571 || prob(true_action): 7.812E-03 || last reward: -0.019
# 	 --> iter: 4 || auroc 0.583 || acc: 0.571 || prob(true_action): 8.142E-03 || last reward: 0.000
# 	 --> iter: 5 || auroc 0.625 || acc: 0.571 || prob(true_action): 8.401E-03 || last reward: 0.000
# 	 --> iter: 6 || auroc 0.667 || acc: 0.571 || prob(true_action): 8.819E-03 || last reward: -0.026
# 	 --> iter: 7 || auroc 0.667 || acc: 0.571 || prob(true_action): 9.120E-03 || last reward: -0.011
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 32
#      27 hoptim = REINFORCE(env, n_actions, action_labels=true_action, clip=10, eps=1e-8, warmup=3, verbose=True,
#      28                         entropy=0., entropy_decay=0.99, min_entropy=0.0, window=10,
#      29                         init_prob=0.5, lr=1e-1, policy_decay=1.)
#      31 for iter in range(100):
# ---> 32     hoptim.step()
#
# File ~/local/GSNN/gsnn/optim/REINFORCE.py:123, in REINFORCE.step(self)
#     121 policy = Bernoulli(logits=self.logits)
#     122 action = policy.sample()
# --> 123 rewards = self.env.run(action)
#     125 advantages = self.scale(rewards).mean()
#     127 if len(self.rewards) >= self.warmup:
#
# File ~/local/GSNN/gsnn/optim/Environment.py:266, in Environment.run(self, action)
#     264 # train model
#     265 try:
# --> 266     reward = self.train(edge_index_dict)
#     267 except:
#     268     # failed trials will result in low reward; e.g., nan divergences
#     269     reward = -1
#
# File ~/local/GSNN/gsnn/optim/Environment.py:209, in Environment.train(self, edge_index_dict)
#     206     if self.verbose: print(f'[batch: {i+1}/{len(train_loader)}]', end='\r')
#     208 # validation perf
# --> 209 y,yhat,_ = utils.predict_gsnn(val_loader, model, device=device, verbose=False)
#     211 # since we have a multioutput prediction problem, we need to return multioutput performances
#     214 if self.metric == 'mse':
#
# File ~/local/GSNN/gsnn/models/utils.py:327, in predict_gsnn(loader, model, device, verbose)
#     324 for i,(x, y, *sig_id) in enumerate(loader):
#     325     if verbose: print(f'progress: {i}/{len(loader)}', end='\r')
# --> 327     yhat = model(x.to(device))
#     329     y = y.to(device)
#     331     yhat = yhat.detach().cpu()
#
# File ~/miniconda3/envs/gsnn-lib/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gsnn-lib/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/local/GSNN/gsnn/models/tGSNN.py:216, in tGSNN.forward(self, x)
#     212 token_embeddings = self._create_token_embeddings(x)  # [batch_size, num_nodes, d_model]
#     214 # Apply transformer with attention masking
#     215 # Note: PyTorch transformer expects mask where True = masked (no attention)
# --> 216 transformer_output = self.transformer_encoder(
#     217     token_embeddings,
#     218     src_key_padding_mask=None,  # We don't mask any tokens
#     219     mask=self.attention_mask
#     220 )  # [batch_size, num_nodes, d_model]
#     222 # Extract output node representations
#     223 output_indices = self.output_node_mask.nonzero(as_tuple=True)[0]
#
# File ~/miniconda3/envs/gsnn-lib/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gsnn-lib/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/miniconda3/envs/gsnn-lib/lib/python3.12/site-packages/torch/nn/modules/transformer.py:416, in TransformerEncoder.forward(self, src, mask, src_key_padding_mask, is_causal)
#     413 is_causal = _detect_is_causal_mask(mask, is_causal, seq_len)
#     415 for mod in self.layers:
# --> 416     output = mod(output, src_mask=mask, is_causal=is_causal, src_key_padding_mask=src_key_padding_mask_for_layers)
#     418 if convert_to_nested:
#     419     output = output.to_padded_tensor(0., src.size())
#
# File ~/miniconda3/envs/gsnn-lib/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gsnn-lib/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/miniconda3/envs/gsnn-lib/lib/python3.12/site-packages/torch/nn/modules/transformer.py:750, in TransformerEncoderLayer.forward(self, src, src_mask, src_key_padding_mask, is_causal)
#     748 else:
#     749     x = self.norm1(x + self._sa_block(x, src_mask, src_key_padding_mask, is_causal=is_causal))
# --> 750     x = self.norm2(x + self._ff_block(x))
#     752 return x
#
# File ~/miniconda3/envs/gsnn-lib/lib/python3.12/site-packages/torch/nn/modules/transformer.py:765, in TransformerEncoderLayer._ff_block(self, x)
#     764 def _ff_block(self, x: Tensor) -> Tensor:
# --> 765     x = self.linear2(self.dropout(self.activation(self.linear1(x))))
#     766     return self.dropout2(x)
#
# File ~/miniconda3/envs/gsnn-lib/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/gsnn-lib/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/miniconda3/envs/gsnn-lib/lib/python3.12/site-packages/torch/nn/modules/linear.py:117, in Linear.forward(self, input)
#     116 def forward(self, input: Tensor) -> Tensor:
# --> 117     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame({'true_action':[(a == true_action).all() for a in hoptim.actions], 'reward':hoptim.rewards})
df = df.assign(rank=(-df['reward']).rank(method='first'))
df = df.assign(action = [x.tolist() for x in hoptim.actions])
_bins = np.linspace(min(df['reward']), max(df['reward']), 100)

plt.figure(figsize=(10,2)) 
plt.hist(df[lambda x: x.true_action]['reward'], color='r', alpha=0.25, label='True action', density=True, bins=_bins)
plt.hist(df[lambda x: ~x.true_action]['reward'], color='b', alpha=0.25, label='False action', density=True, bins=_bins)
plt.legend()
plt.title('Reward distribution')
plt.xlabel('Reward')
plt.ylabel('Density')
plt.yscale('log')
plt.show()

# %%
best_action = hoptim.best_action.detach().cpu().numpy().ravel()
policy = hoptim.logits.sigmoid().detach().cpu().numpy().ravel()

print('Was the true action tested/explored?', df.true_action.any())
if df.true_action.any(): print('\tRank of true action:', df[lambda x: x.true_action]['rank'].min())

print('policy', policy)
print('best_action', best_action)
print('true_action', true_action)

acc = np.mean(best_action == true_action)
auroc = roc_auc_score(true_action, policy)

print(f'best action accuracy: {acc:.3f}')
print(f'final policy auroc: {auroc:.3f}')

# plot  confusion matrix 
cm = confusion_matrix(true_action, best_action)

plt.figure() 
sbn.heatmap(cm, annot=True, fmt='d', cmap='Blues') 
plt.title('Best-action Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Was the true action tested/explored? True
# 	Rank of true action: 1.0
# policy [0.9625665  0.97028977 0.96469605 0.20281745 0.54498446 0.34750575
#  0.1811429 ]
# best_action [1. 1. 1. 0. 0. 0. 0.]
# true_action [1. 1. 1. 0. 0. 0. 0.]
# best action accuracy: 1.000
# final policy auroc: 1.000

# %%
avg_reward = np.array(hoptim.rewards)
plt.figure() 
plt.plot(avg_reward)
plt.plot(pd.Series(avg_reward).rolling(window=10).mean())

plt.xlabel('iteration')
plt.ylabel('average reward')
plt.show()
